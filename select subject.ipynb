# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data_all.csv')
data.head()
# Out:
#    Subject  Session  Block CorrectResponse  event  finalRT  firstACC  \
# 0      101        1      1               m      4      532         1
# 1      101        1      1               b      3      627         1
# 2      101        1      1               b      3      580         1
# 3      101        1      1               c      2      590         1
# 4      101        1      1               m      4      544         1
#
#   firstRESP  measured_RT TrialType  ...  e_to_c_distance_from_last_bigram  \
# 0         m          532      Prac  ...                               NaN
# 1         b          627      Prac  ...                               NaN
# 2         b          580      Prac  ...                               NaN
# 3         c          590      Prac  ...                               NaN
# 4         m          544      Prac  ...                               NaN
#
#   e_to_c_distance_from_last_trigram c_to_e_distance_from_last_unigram  \
# ...

# %%
data_101 = data[data['Subject']== 101]

# %%
data_101['Subject'].nunique()
# Out:
# 1

# %%
data_101.to_csv('data_101.csv')
